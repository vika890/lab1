# %%
import os
import random
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import timm
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)
lr = 0.0001
model_name = 'resnet18'
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')
# Out:
# Using device: cpu

# %%
# Transforms
train_transforms = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomRotation(15),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
    transforms.RandomResizedCrop(224, scale=(0.8, 1.0)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

val_test_transforms = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Datasets
train_dataset = datasets.ImageFolder('../data/split/train', transform=train_transforms)
val_dataset = datasets.ImageFolder('../data/split/val', transform=val_test_transforms)
test_dataset = datasets.ImageFolder('../data/split/test', transform=val_test_transforms)

# DataLoaders
batch_size = 16
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

print(f'Train: {len(train_dataset)}, Val: {len(val_dataset)}, Test: {len(test_dataset)}')
# Out:
# Train: 63, Val: 12, Test: 15

# %%
models = {
    'resnet18': timm.create_model('resnet18', pretrained=True, num_classes=3),
    'efficientnet_b0': timm.create_model('efficientnet_b0', pretrained=True, num_classes=3)
}

# %%
def freeze_layers(model, model_name, num_unfrozen_layers=0):
    # Freeze all parameters
    for param in model.parameters():
        param.requires_grad = False

    # Unfreeze the FC layer based on model architecture
    if 'resnet' in model_name.lower():
        for param in model.fc.parameters():
            param.requires_grad = True
    elif 'efficientnet' in model_name.lower():
        for param in model.classifier.parameters():
            param.requires_grad = True

    # Optionally unfreeze additional layers
    if num_unfrozen_layers > 0:
        for param in list(model.parameters())[-num_unfrozen_layers:]:
            param.requires_grad = True

# %% [markdown]
# ResNet18

# %%
freeze_layers(models['resnet18'], model_name='resnet18', num_unfrozen_layers=0)
models['resnet18'].fc.requires_grad_(True)
# Out:
# Linear(in_features=512, out_features=3, bias=True)

# %%
for param in models['resnet18'].layer4.parameters():
    param.requires_grad = True

# %%
def train_and_evaluate(model, train_loader, val_loader, config):
    model = model.to(config['device'])
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.AdamW(model.parameters(), lr=config['lr'])
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=3)

    train_losses, val_losses = [], []
    train_accuracies, val_accuracies = [], []

    for epoch in range(config['epochs']):
        model.train()
        train_loss, train_preds, train_labels = 0.0, [], []
        for images, labels in train_loader:
            images, labels = images.to(config['device']), labels.to(config['device'])
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            train_loss += loss.item() * images.size(0)
            train_preds.extend(outputs.argmax(dim=1).cpu().numpy())
            train_labels.extend(labels.cpu().numpy())

        train_loss /= len(train_loader.dataset)
        train_acc = accuracy_score(train_labels, train_preds)
        train_losses.append(train_loss)
        train_accuracies.append(train_acc)

        # Validation
        model.eval()
        val_loss, val_preds, val_labels = 0.0, [], []
        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(config['device']), labels.to(config['device'])
                outputs = model(images)
                loss = criterion(outputs, labels)
                val_loss += loss.item() * images.size(0)
                val_preds.extend(outputs.argmax(dim=1).cpu().numpy())
                val_labels.extend(labels.cpu().numpy())

        val_loss /= len(val_loader.dataset)
        val_acc = accuracy_score(val_labels, val_preds)
        val_losses.append(val_loss)
        val_accuracies.append(val_acc)

        scheduler.step(val_loss)
        print(f"Epoch {epoch+1}/{config['epochs']}: Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}, Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}")

    # Сохранение модели
    os.makedirs('models', exist_ok=True)
    save_path = f"models/{config['model_name']}_bs{config['batch_size']}_lr{config['lr']}.pth"
    torch.save(model.state_dict(), save_path)
    print(f"Модель сохранена: {save_path}")

    return train_losses, val_losses, train_accuracies, val_accuracies, val_preds, val_labels

# %%
config = {'lr': lr, 'epochs': 10, 'device': device, 'model_name': model_name}

# %%
batch_sizes = [8, 16]
lrs = [1e-5, 1e-4]
results = {}

for model_name, model in models.items():
    for bs in batch_sizes:
        for lr in lrs:
            print(f'Обучение {model_name} с batch_size={bs}, lr={lr}')
            train_loader = DataLoader(train_dataset, batch_size=bs, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=bs, shuffle=False)
            config = {'lr': lr, 'epochs': 10, 'device': device, 'model_name': model_name, 'batch_size': bs}
            freeze_layers(model, model_name, num_unfrozen_layers=0)
            print(f"Размороженные параметры для {model_name}:", [name for name, param in model.named_parameters() if param.requires_grad])
            results[f'{model_name}_bs{bs}_lr{lr}'] = train_and_evaluate(model, train_loader, val_loader, config)
# Out:
# Обучение resnet18 с batch_size=8, lr=1e-05
# Размороженные параметры для resnet18: ['fc.weight', 'fc.bias']
# Epoch 1/10: Train Loss: 1.1356, Train Acc: 0.1429, Val Loss: 1.1271, Val Acc: 0.2500
# Epoch 2/10: Train Loss: 1.1270, Train Acc: 0.2857, Val Loss: 1.1197, Val Acc: 0.2500
# Epoch 3/10: Train Loss: 1.1351, Train Acc: 0.1587, Val Loss: 1.1170, Val Acc: 0.2500
# Epoch 4/10: Train Loss: 1.1343, Train Acc: 0.2381, Val Loss: 1.1190, Val Acc: 0.3333
# Epoch 5/10: Train Loss: 1.1225, Train Acc: 0.3016, Val Loss: 1.1117, Val Acc: 0.2500
# Epoch 6/10: Train Loss: 1.1274, Train Acc: 0.2381, Val Loss: 1.1136, Val Acc: 0.2500
# Epoch 7/10: Train Loss: 1.1427, Train Acc: 0.2063, Val Loss: 1.1155, Val Acc: 0.2500
# Epoch 8/10: Train Loss: 1.1219, Train Acc: 0.2698, Val Loss: 1.1141, Val Acc: 0.2500
# Epoch 9/10: Train Loss: 1.1323, Train Acc: 0.2222, Val Loss: 1.1160, Val Acc: 0.2500
# Epoch 10/10: Train Loss: 1.1144, Train Acc: 0.3016, Val Loss: 1.1162, Val Acc: 0.2500
# Модель сохранена: models/resnet18_bs8_lr1e-05.pth
# Обучение resnet18 с batch_size=8, lr=0.0001
# Размороженные параметры для resnet18: ['fc.weight', 'fc.bias']
# Epoch 1/10: Train Loss: 1.1143, Train Acc: 0.3016, Val Loss: 1.1108, Val Acc: 0.2500
# Epoch 2/10: Train Loss: 1.0987, Train Acc: 0.3651, Val Loss: 1.1004, Val Acc: 0.2500
# Epoch 3/10: Train Loss: 1.0999, Train Acc: 0.3492, Val Loss: 1.0933, Val Acc: 0.2500
# Epoch 4/10: Train Loss: 1.0729, Train Acc: 0.4762, Val Loss: 1.0821, Val Acc: 0.3333
# Epoch 5/10: Train Loss: 1.0860, Train Acc: 0.3492, Val Loss: 1.0797, Val Acc: 0.4167
# Epoch 6/10: Train Loss: 1.0721, Train Acc: 0.4762, Val Loss: 1.0711, Val Acc: 0.5000
# Epoch 7/10: Train Loss: 1.0656, Train Acc: 0.4921, Val Loss: 1.0620, Val Acc: 0.5000
# Epoch 8/10: Train Loss: 1.0660, Train Acc: 0.4444, Val Loss: 1.0561, Val Acc: 0.5000
# Epoch 9/10: Train Loss: 1.0407, Train Acc: 0.6190, Val Loss: 1.0472, Val Acc: 0.5833
# Epoch 10/10: Train Loss: 1.0371, Train Acc: 0.5556, Val Loss: 1.0408, Val Acc: 0.5833
# Модель сохранена: models/resnet18_bs8_lr0.0001.pth
# Обучение resnet18 с batch_size=16, lr=1e-05
# Размороженные параметры для resnet18: ['fc.weight', 'fc.bias']
# Epoch 1/10: Train Loss: 1.0364, Train Acc: 0.5714, Val Loss: 1.0367, Val Acc: 0.5833
# Epoch 2/10: Train Loss: 1.0127, Train Acc: 0.7143, Val Loss: 1.0373, Val Acc: 0.5833
# Epoch 3/10: Train Loss: 1.0255, Train Acc: 0.6349, Val Loss: 1.0336, Val Acc: 0.5833
# Epoch 4/10: Train Loss: 1.0507, Train Acc: 0.4762, Val Loss: 1.0305, Val Acc: 0.5833
# Epoch 5/10: Train Loss: 1.0446, Train Acc: 0.6032, Val Loss: 1.0319, Val Acc: 0.5833
# Epoch 6/10: Train Loss: 1.0191, Train Acc: 0.6508, Val Loss: 1.0327, Val Acc: 0.5833
# Epoch 7/10: Train Loss: 1.0256, Train Acc: 0.6349, Val Loss: 1.0317, Val Acc: 0.5833
# Epoch 8/10: Train Loss: 1.0245, Train Acc: 0.6190, Val Loss: 1.0302, Val Acc: 0.5833
# Epoch 9/10: Train Loss: 1.0478, Train Acc: 0.5397, Val Loss: 1.0316, Val Acc: 0.5833
# Epoch 10/10: Train Loss: 1.0163, Train Acc: 0.6667, Val Loss: 1.0320, Val Acc: 0.5833
# Модель сохранена: models/resnet18_bs16_lr1e-05.pth
# Обучение resnet18 с batch_size=16, lr=0.0001
# Размороженные параметры для resnet18: ['fc.weight', 'fc.bias']
# Epoch 1/10: Train Loss: 1.0240, Train Acc: 0.6349, Val Loss: 1.0282, Val Acc: 0.5833
# Epoch 2/10: Train Loss: 1.0210, Train Acc: 0.6190, Val Loss: 1.0239, Val Acc: 0.5833
# Epoch 3/10: Train Loss: 1.0118, Train Acc: 0.6349, Val Loss: 1.0171, Val Acc: 0.5833
# Epoch 4/10: Train Loss: 1.0133, Train Acc: 0.6508, Val Loss: 1.0099, Val Acc: 0.6667
# Epoch 5/10: Train Loss: 1.0040, Train Acc: 0.6984, Val Loss: 1.0044, Val Acc: 0.7500
# Epoch 6/10: Train Loss: 1.0024, Train Acc: 0.6825, Val Loss: 1.0006, Val Acc: 0.7500
# Epoch 7/10: Train Loss: 1.0086, Train Acc: 0.5873, Val Loss: 0.9908, Val Acc: 0.8333
# Epoch 8/10: Train Loss: 0.9946, Train Acc: 0.7143, Val Loss: 0.9866, Val Acc: 0.8333
# Epoch 9/10: Train Loss: 0.9719, Train Acc: 0.7778, Val Loss: 0.9832, Val Acc: 0.8333
# Epoch 10/10: Train Loss: 0.9705, Train Acc: 0.7302, Val Loss: 0.9760, Val Acc: 0.8333
# Модель сохранена: models/resnet18_bs16_lr0.0001.pth
# Обучение efficientnet_b0 с batch_size=8, lr=1e-05
# Размороженные параметры для efficientnet_b0: ['classifier.weight', 'classifier.bias']
# Epoch 1/10: Train Loss: 2.6483, Train Acc: 0.4127, Val Loss: 4.6449, Val Acc: 0.3333
# Epoch 2/10: Train Loss: 3.0182, Train Acc: 0.3492, Val Loss: 4.2631, Val Acc: 0.5000
# Epoch 3/10: Train Loss: 3.6427, Train Acc: 0.3016, Val Loss: 3.9676, Val Acc: 0.5833
# Epoch 4/10: Train Loss: 2.9400, Train Acc: 0.3651, Val Loss: 4.0839, Val Acc: 0.5833
# Epoch 5/10: Train Loss: 2.8042, Train Acc: 0.4286, Val Loss: 4.0146, Val Acc: 0.5833
# Epoch 6/10: Train Loss: 2.8816, Train Acc: 0.4127, Val Loss: 3.6943, Val Acc: 0.6667
# Epoch 7/10: Train Loss: 2.6713, Train Acc: 0.4127, Val Loss: 3.8283, Val Acc: 0.5833
# Epoch 8/10: Train Loss: 2.9608, Train Acc: 0.3968, Val Loss: 3.9473, Val Acc: 0.5000
# Epoch 9/10: Train Loss: 3.4552, Train Acc: 0.3175, Val Loss: 3.5724, Val Acc: 0.5833
# Epoch 10/10: Train Loss: 3.2798, Train Acc: 0.3968, Val Loss: 3.6216, Val Acc: 0.6667
# Модель сохранена: models/efficientnet_b0_bs8_lr1e-05.pth
# Обучение efficientnet_b0 с batch_size=8, lr=0.0001
# Размороженные параметры для efficientnet_b0: ['classifier.weight', 'classifier.bias']
# Epoch 1/10: Train Loss: 3.1866, Train Acc: 0.3968, Val Loss: 3.7200, Val Acc: 0.6667
# Epoch 2/10: Train Loss: 2.6146, Train Acc: 0.4603, Val Loss: 3.8565, Val Acc: 0.5833
# Epoch 3/10: Train Loss: 2.7385, Train Acc: 0.4444, Val Loss: 3.6717, Val Acc: 0.5833
# Epoch 4/10: Train Loss: 2.9649, Train Acc: 0.3651, Val Loss: 3.6064, Val Acc: 0.6667
# Epoch 5/10: Train Loss: 2.8652, Train Acc: 0.3651, Val Loss: 3.5880, Val Acc: 0.5833
# Epoch 6/10: Train Loss: 2.8136, Train Acc: 0.3810, Val Loss: 3.4129, Val Acc: 0.5000
# Epoch 7/10: Train Loss: 2.6944, Train Acc: 0.4286, Val Loss: 3.3925, Val Acc: 0.5833
# Epoch 8/10: Train Loss: 2.3408, Train Acc: 0.5079, Val Loss: 3.4786, Val Acc: 0.5000
# Epoch 9/10: Train Loss: 2.1218, Train Acc: 0.4286, Val Loss: 3.6105, Val Acc: 0.5833
# Epoch 10/10: Train Loss: 2.1456, Train Acc: 0.5238, Val Loss: 3.5563, Val Acc: 0.5833
# Модель сохранена: models/efficientnet_b0_bs8_lr0.0001.pth
# Обучение efficientnet_b0 с batch_size=16, lr=1e-05
# Размороженные параметры для efficientnet_b0: ['classifier.weight', 'classifier.bias']
# Epoch 1/10: Train Loss: 2.1186, Train Acc: 0.5079, Val Loss: 3.5984, Val Acc: 0.5833
# Epoch 2/10: Train Loss: 2.1853, Train Acc: 0.4444, Val Loss: 3.5114, Val Acc: 0.5833
# Epoch 3/10: Train Loss: 2.3231, Train Acc: 0.4286, Val Loss: 3.5639, Val Acc: 0.6667
# Epoch 4/10: Train Loss: 2.6850, Train Acc: 0.4444, Val Loss: 3.6095, Val Acc: 0.6667
# Epoch 5/10: Train Loss: 2.7556, Train Acc: 0.4603, Val Loss: 3.5439, Val Acc: 0.6667
# Epoch 6/10: Train Loss: 2.2630, Train Acc: 0.4603, Val Loss: 3.6127, Val Acc: 0.6667
# Epoch 7/10: Train Loss: 2.9298, Train Acc: 0.4444, Val Loss: 3.6086, Val Acc: 0.5833
# Epoch 8/10: Train Loss: 2.2213, Train Acc: 0.4603, Val Loss: 3.7154, Val Acc: 0.6667
# Epoch 9/10: Train Loss: 2.5052, Train Acc: 0.4444, Val Loss: 3.6631, Val Acc: 0.6667
# Epoch 10/10: Train Loss: 2.6182, Train Acc: 0.4286, Val Loss: 3.6483, Val Acc: 0.6667
# Модель сохранена: models/efficientnet_b0_bs16_lr1e-05.pth
# Обучение efficientnet_b0 с batch_size=16, lr=0.0001
# Размороженные параметры для efficientnet_b0: ['classifier.weight', 'classifier.bias']
# Epoch 1/10: Train Loss: 2.6365, Train Acc: 0.4286, Val Loss: 3.5312, Val Acc: 0.6667
# Epoch 2/10: Train Loss: 2.1409, Train Acc: 0.4444, Val Loss: 3.5655, Val Acc: 0.6667
# Epoch 3/10: Train Loss: 1.7882, Train Acc: 0.5556, Val Loss: 3.5497, Val Acc: 0.6667
# Epoch 4/10: Train Loss: 2.0298, Train Acc: 0.4762, Val Loss: 3.3596, Val Acc: 0.6667
# Epoch 5/10: Train Loss: 2.2842, Train Acc: 0.4762, Val Loss: 3.2626, Val Acc: 0.6667
# Epoch 6/10: Train Loss: 2.1888, Train Acc: 0.4762, Val Loss: 3.2820, Val Acc: 0.6667
# Epoch 7/10: Train Loss: 2.2144, Train Acc: 0.5079, Val Loss: 3.3708, Val Acc: 0.6667
# Epoch 8/10: Train Loss: 2.2219, Train Acc: 0.4286, Val Loss: 3.3700, Val Acc: 0.6667
# Epoch 9/10: Train Loss: 1.8429, Train Acc: 0.6032, Val Loss: 3.4600, Val Acc: 0.6667
# Epoch 10/10: Train Loss: 1.8305, Train Acc: 0.5079, Val Loss: 3.5355, Val Acc: 0.6667
# Модель сохранена: models/efficientnet_b0_bs16_lr0.0001.pth

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Создаем папку для графиков
os.makedirs('plots', exist_ok=True)

def plot_learning_curves(results, model_name, batch_size, lr, show_plot=True):
    # Извлекаем результаты для конкретной комбинации
    train_losses, val_losses, train_accuracies, val_accuracies, _, _ = results[f'{model_name}_bs{batch_size}_lr{lr}']
    
    # Создаем график
    plt.figure(figsize=(12, 4))
    
    # График Loss
    plt.subplot(1, 2, 1)
    plt.plot(train_losses, label='Train Loss', marker='o')
    plt.plot(val_losses, label='Val Loss', marker='s')
    plt.title(f'{model_name} (bs={batch_size}, lr={lr}) - Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    
    # График Accuracy
    plt.subplot(1, 2, 2)
    plt.plot(train_accuracies, label='Train Acc', marker='o')
    plt.plot(val_accuracies, label='Val Acc', marker='s')
    plt.title(f'{model_name} (bs={batch_size}, lr={lr}) - Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    
    # Сохраняем график (всегда)
    save_path = f'plots/{model_name}_bs{batch_size}_lr{lr}.png'
    plt.savefig(save_path)
    print(f'График сохранен: {save_path}')
    
    # Показываем график на экране (только если нужно)
    if show_plot:
        plt.show()
    
    # Закрываем график, чтобы не отображать его автоматически
    plt.close()
    
    return val_accuracies[-1]  # Возвращаем финальную точность на валидации

bs_values = [8, 16] 
lr = 0.0001

best_val_acc = 0
best_key = None
best_params = None

# Сначала сохраняем все графики и находим лучший
for model_name in models.keys():
    for bs in bs_values:
        key = f'{model_name}_bs{bs}_lr{lr}' 
        if key in results: 
            val_acc = plot_learning_curves(results, model_name, bs, lr, show_plot=False)
            print(f'{key}: Val Acc = {val_acc:.4f}')
            
            # Проверяем, является ли это лучшим результатом
            if val_acc > best_val_acc:
                best_val_acc = val_acc
                best_key = key
                best_params = (model_name, bs, lr)
        else: 
            print(f'Результаты для {key} отсутствуют')

# Выводим лучший график
print(f'\nЛучшая модель: {best_key} с точностью {best_val_acc:.4f}')
model_name, bs, lr = best_params
_ = plot_learning_curves(results, model_name, bs, lr, show_plot=True)
# Out:
# График сохранен: plots/resnet18_bs8_lr0.0001.png
# resnet18_bs8_lr0.0001: Val Acc = 0.5833
# График сохранен: plots/resnet18_bs16_lr0.0001.png
# resnet18_bs16_lr0.0001: Val Acc = 0.8333
# График сохранен: plots/efficientnet_b0_bs8_lr0.0001.png
# efficientnet_b0_bs8_lr0.0001: Val Acc = 0.5833
# График сохранен: plots/efficientnet_b0_bs16_lr0.0001.png
# efficientnet_b0_bs16_lr0.0001: Val Acc = 0.6667
#
# Лучшая модель: resnet18_bs16_lr0.0001 с точностью 0.8333
# График сохранен: plots/resnet18_bs16_lr0.0001.png

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Матрица ошибок для лучшей модели
model_name, batch_size, lr = best_params
key = f'{model_name}_bs{batch_size}_lr{lr}'
train_losses, val_losses, train_accuracies, val_accuracies, val_preds, val_labels = results[key]

plt.figure(figsize=(5, 4)) 
cm_val = confusion_matrix(val_labels, val_preds) 
sns.heatmap(cm_val, annot=True, fmt='d', cmap='Blues', 
            xticklabels=train_dataset.classes, 
            yticklabels=train_dataset.classes, 
            annot_kws={'size': 14}, 
            cbar_kws={'shrink': 0.8}) 

plt.xlabel('Predicted', fontsize=12) 
plt.ylabel('True', fontsize=12) 
plt.title(f'Confusion Matrix: {model_name} (bs={batch_size}, lr={lr})', fontsize=14, fontweight='bold') 
plt.tight_layout() 
plt.savefig(f'plots/{model_name}_confusion_matrix.png', dpi=150, bbox_inches='tight') 
plt.show()

# %%
import torch
import timm
import onnx
import os

def export_to_onnx(model_name, model_path, onnx_path, input_shape=(1, 3, 224, 224), device='cpu'):
    # Загружаем модель
    model = timm.create_model(model_name, pretrained=False, num_classes=3)
    model.load_state_dict(torch.load(model_path, map_location=device))
    model = model.to(device)
    model.eval()

    # Создаем фиктивный входной тензор
    dummy_input = torch.randn(input_shape).to(device)

    # Экспортируем модель в ONNX
    torch.onnx.export(
        model,
        dummy_input,
        onnx_path,
        export_params=True,
        opset_version=18,  # Используем более новую версию opset
        do_constant_folding=True,
        input_names=['input'],  # Имя входного тензора
        output_names=['output'],  # Имя выходного тензора
        dynamic_axes={'input': {0: 'batch_size'}, 'output': {0: 'batch_size'}}  # Указываем динамическую ось для batch_size
    )
    print(f"Модель экспортирована в {onnx_path}")

    # Проверяем корректность ONNX модели
    onnx_model = onnx.load(onnx_path)
    onnx.checker.check_model(onnx_model)
    print(f"ONNX модель проверена успешно")

# Параметры
best_model_name = 'resnet18'
best_model_path = 'models/resnet18_bs16_lr0.0001.pth'
onnx_path = f'models/{best_model_name}_bs16_lr0.0001.onnx'

# Экспорт
os.makedirs('models', exist_ok=True)
export_to_onnx(best_model_name, best_model_path, onnx_path, device='cpu')
# Out:
# /tmp/ipykernel_234968/2609109077.py:17: UserWarning: # 'dynamic_axes' is not recommended when dynamo=True, and may lead to 'torch._dynamo.exc.UserError: Constraints violated.' Supply the 'dynamic_shapes' argument instead if export is unsuccessful.
#   torch.onnx.export(
# W0301 16:35:00.653000 234968 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'input' from (input, boxes, output_size: 'Sequence[int]', spatial_scale: 'float' = 1.0, sampling_ratio: 'int' = -1, aligned: 'bool' = False). Treating as an Input.
# W0301 16:35:00.655000 234968 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'boxes' from (input, boxes, output_size: 'Sequence[int]', spatial_scale: 'float' = 1.0, sampling_ratio: 'int' = -1, aligned: 'bool' = False). Treating as an Input.
# W0301 16:35:00.657000 234968 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'input' from (input, boxes, output_size: 'Sequence[int]', spatial_scale: 'float' = 1.0). Treating as an Input.
# W0301 16:35:00.660000 234968 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'boxes' from (input, boxes, output_size: 'Sequence[int]', spatial_scale: 'float' = 1.0). Treating as an Input.
# [torch.onnx] Obtain model graph for `ResNet([...]` with `torch.export.export(..., strict=False)`...
# [torch.onnx] Obtain model graph for `ResNet([...]` with `torch.export.export(..., strict=False)`... ✅
# [torch.onnx] Run decomposition...
# /usr/lib/python3.12/copyreg.py:99: FutureWarning: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
#   return cls.__new__(cls, *args)
# [torch.onnx] Run decomposition... ✅
# [torch.onnx] Translate the graph into ONNX...
# [torch.onnx] Translate the graph into ONNX... ✅
# Applied 41 of general pattern rewrite rules.
# Модель экспортирована в models/resnet18_bs16_lr0.0001.onnx
# ONNX модель проверена успешно
